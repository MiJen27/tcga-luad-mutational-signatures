# %% [markdown]
# # 01 — Setup
#
# This notebook prepares the environment for the TCGA-LUAD workflow.
#
# It uses:
# - `requirements.txt` for Python packages,
# - the GRCh38 reference download for SigProfiler,
# - simple folder checks before the analysis starts.

# %% [markdown]
# ## 1. Install Python packages
#
# Run this cell once.
# If the notebook still complains about missing packages after installation, restart the kernel and continue.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas==2.3.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: numpy==2.2.6 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.2.6)
# Requirement already satisfied: matplotlib==3.10.7 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.10.7)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy==1.15.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: SigProfilerAssignment==1.0.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: SigProfilerMatrixGenerator==1.3.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.3.5)
# Requirement already satisfied: sigProfilerPlotting==1.4.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.4.1)
# Requirement already satisfied: imblearn==0.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.0)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (4.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas==2.3.3->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas==2.3.3->-r requirements.txt (line 1)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas==2.3.3->-r requirements.txt (line 1)) (2026.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (4.63.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (12.2.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (26.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.10.7->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: reportlab>=3.5.42 in ./.venv/lib/python3.10/site-packages (from SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (4.5.1)
# Requirement already satisfied: pdf2image>=1.16.0 in ./.venv/lib/python3.10/site-packages (from SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: alive_progress>=2.4.1 in ./.venv/lib/python3.10/site-packages (from SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: pypdf>=6.0.0 in ./.venv/lib/python3.10/site-packages (from SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (6.11.0)
# Requirement already satisfied: statsmodels>=0.9.0 in ./.venv/lib/python3.10/site-packages (from SigProfilerMatrixGenerator==1.3.5->-r requirements.txt (line 7)) (0.14.6)
# Requirement already satisfied: scikit-learn>=1.1.3 in ./.venv/lib/python3.10/site-packages (from sigProfilerPlotting==1.4.1->-r requirements.txt (line 8)) (1.7.2)
# Requirement already satisfied: imbalanced-learn in ./.venv/lib/python3.10/site-packages (from imblearn==0.0->-r requirements.txt (line 9)) (0.14.1)
# Requirement already satisfied: tornado>=6.2.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (6.5.5)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (0.2.4)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (63.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: tomli>=1.2.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (2.4.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (2.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (2.18.2)
# Requirement already satisfied: jupyter-core in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (5.9.1)
# Requirement already satisfied: traitlets in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (5.15.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 10)) (7.2.0)
# Requirement already satisfied: graphemeu==0.7.2 in ./.venv/lib/python3.10/site-packages (from alive_progress>=2.4.1->SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: about-time==4.2.1 in ./.venv/lib/python3.10/site-packages (from alive_progress>=2.4.1->SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (4.2.1)
# Requirement already satisfied: typing_extensions>=4.0.0 in ./.venv/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab->-r requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (3.15)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (2026.4.22)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (8.39.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (7.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (1.8.20)
# Requirement already satisfied: jupyter-client>=8.8.0 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (8.8.0)
# Requirement already satisfied: appnope>=0.1.2 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (27.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.10/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 10)) (4.9.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (7.7.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (5.10.4)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.25.0)
# Requirement already satisfied: nbconvert>=6.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (7.17.1)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (0.14.0)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (2.34.1)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (4.26.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.3.3->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset-normalizer in ./.venv/lib/python3.10/site-packages (from reportlab>=3.5.42->SigProfilerAssignment==1.0.0->-r requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.1.3->sigProfilerPlotting==1.4.1->-r requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.1.3->sigProfilerPlotting==1.4.1->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.10/site-packages (from statsmodels>=0.9.0->SigProfilerMatrixGenerator==1.3.5->-r requirements.txt (line 7)) (1.0.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in ./.venv/lib/python3.10/site-packages (from imbalanced-learn->imblearn==0.0->-r requirements.txt (line 9)) (0.1.5)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (3.0.52)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (26.1.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (0.30.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (0.37.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.10.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (6.3.0)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.3.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (4.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (2.21.2)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (2.7.0)
# Requirement already satisfied: ptyprocess in ./.venv/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.8.7)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (3.1.1)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (25.10.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (20.11.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (2.8.3)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 10)) (3.0.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 10)) (3.0)
# Requirement already satisfied: lark>=1.2.2 in ./.venv/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 10)) (1.4.0)
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Download the GRCh38 reference for SigProfiler
#
# This is the only extra reference download needed for the pipeline.

# %%
from SigProfilerMatrixGenerator import install as gen_install

gen_install.install("GRCh38", rsync=False, bash=True)
# Out:
# Tool       | Installed
# INFO - Downloading GRCh38...
# -----------------------
# curl       | True
# wget       | False
# rsync      | True
# Downloading: 100.00% [786.36 MB of 786.36 MB] at 13.46 MB/s
# Download complete.
# INFO - Downloaded GRCh38 from alexandrovlab using FTP.
# INFO - GRCh38 has been successfully installed.
# All reference files have been created.
# To proceed with matrix_generation, please provide the path to your vcf files and an appropriate output path.
# Installation complete.

# %% [markdown]
# ## 3. Quick note
#
# Recommended notebook order:
# 1. `01_setup_environment.ipynb`
# 2. `02_sigprofiler_generation_and_fitting.ipynb`
# 3. `03a_merge_clinical_and_exposure.ipynb`
# 4. `03b_basic_cohort_plots.ipynb`
# 5. `04_unsupervised_signature_plots.ipynb`
# 6. `05_supervised_data_split.ipynb`
# 7. `06_supervised_balanced_random_forest.ipynb`
